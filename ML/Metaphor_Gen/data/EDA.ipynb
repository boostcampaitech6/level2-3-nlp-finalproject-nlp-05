# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_json('train.json')

# %%
df
# Out:
#     concept-set                   scene
# 0           기쁘다     마음속 풍선이 하늘로 날아가는 순간
# 1           기쁘다         봄날의 따뜻한 햇살 속 산책
# 2           기쁘다        꿈에서 막 깨어난 아침의 설렘
# 3           기쁘다         오랜 친구와 다시 만난 순간
# 4           기쁘다       첫 눈 내리는 밤의 조용한 거리
# ..          ...                     ...
# 995       혼란스럽다      서로 다른 색깔의 실들이 엉킨 공
# 996       혼란스럽다     낡은 지도 위에 표시된 겹치는 길들
# 997       혼란스럽다   책상 위 무질서하게 흩어진 공부 자료들
# 998       혼란스럽다      한바탕 소동 뒤 남겨진 방의 혼란
# 999       혼란스럽다  빠르게 변하는 날씨의 예측 불가능한 패턴
#
# [1000 rows x 2 columns]

# %%
df['senetence_length'] = df['scene'].apply(len)

# %%
plt.figure(figsize=(10, 8))
sns.histplot(df['senetence_length'], bins=30, kde=True)
plt.show()

# %%
df['senetence_length'].describe()
# Out:
# count    1000.000000
# mean       17.927000
# std         2.395289
# min        11.000000
# 25%        16.000000
# 50%        18.000000
# 75%        19.000000
# max        25.000000
# Name: senetence_length, dtype: float64
