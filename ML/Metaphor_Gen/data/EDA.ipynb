# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_json('train_final.json', lines=True)

# %%
df
# Out:
#      concept-set                 scene
# 0            기쁘다        하늘을 수놓은 별빛의 축제
# 1            기쁘다       손에 잡힌 행운의 네잎클로버
# 2            기쁘다     온 세상이 축하하는 당신의 성공
# 3            기쁘다       마음 깊은 곳의 평온한 호수
# 4            기쁘다        꿈에 그리던 이상향의 발견
# ...          ...                   ...
# 1059        짜증나다       끈적한 여름날의 불쾌한 더위
# 1060        짜증나다  귀에서 앵앵거리는 시끄러운 모기 소리
# 1061        짜증나다     바람에 흩어지는 미세먼지의 분노
# 1062        짜증나다    꽉 막힌 도로 위의 끝없는 답답함
# 1063        짜증나다    끊임없이 울리는 새벽의 알람 소리
#
# [1064 rows x 2 columns]

# %%
df['senetence_length'] = df['scene'].apply(len)

# %%
plt.figure(figsize=(10, 8))
sns.histplot(df['senetence_length'], bins=30, kde=True)
plt.show()

# %%
df['senetence_length'].describe()
# Out:
# count    1064.000000
# mean       17.608083
# std         2.580696
# min        10.000000
# 25%        16.000000
# 50%        18.000000
# 75%        19.000000
# max        26.000000
# Name: senetence_length, dtype: float64
